# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import pandas as pd
import xarray as xr
import numpy as np

import glob
import os

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
lat_min=45
lon_min=-60
lat_max=60
lon_max=10

# %%
lon_recovery=-9.8875
lat_recover=53.5384
#osker_id=300434066644040

#lon_recovery_2=-9.444734
#lat_recover_2=52.858339

lat_recovery_3=46.877761
lon_recovery_3=-2.152687
osker_id=300434066647050

# %%
# etopo file
ef = '/home/soontiensn/data/ocn-nav/ETOPO1_Bed_g_gmt4.grd'
etopo = xr.open_dataset(ef)
esel = etopo.sel(x=slice(lon_min, lon_max), y=slice(lat_min, lat_max))

# %%
#stokes = glob.glob('data/stokes_*')
#SVPs = glob.glob('data/SVP_*')
spotter = 'data/SPOT-1759_2022-04-22_2023-10-25_download.csv'
oskers = 'data/OSKERS-SpringAZMP2022-20220526.csv'

# %%
def pretty_map(ax):
    # Add coastlines
    ax.coastlines(linewidth=1)
    # Add gridlines 
    gl = ax.gridlines(linestyle='--',draw_labels={"bottom": "x", "left": "y"},zorder=10)
    ax.add_feature(cfeature.LAND)

# %%
def plot_bathymetry(ax, etopo):
    lons = etopo.x.values
    lats = etopo.y.values
    lons, lats = np.meshgrid(lons,lats)
    bathy = etopo.z.values
    levels = [-1000,]
    CS = ax.contour(lons,lats,bathy,levels, transform=ccrs.PlateCarree(),
                    linestyles='solid', linewidth=0.05,colors='lightgrey')

# %%
def plot_spotter(fname, ax):
    d = pd.read_csv(fname)
    x, y = d['Longitude (deg)'].values, d['Latitude (deg)'].values
    ax.plot(x,y,color='C0', label='SPOT-1759', transform=ccrs.PlateCarree())

# %%
def plot_oskers(files, ax, idplot=None):
    count=0
    for file in files:
        print(file)
        d = pd.read_csv(file)
        dg = d.groupby('Device')
        for name, g in dg:
            x, y = g['Longitude'].values,g['Latitude'].values
            if idplot:
                if name==idplot:
                    ax.plot(x,y,color='C2', lw=3,label='Osker 1321', transform=ccrs.PlateCarree())

# %%
fig = plt.figure(figsize=(9,6))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
#plot_bathymetry(bmap,ax,esel)
plot_spotter(spotter, ax)
plot_oskers([oskers,], ax,idplot=osker_id)
ax.plot(-52.7126,47.5615,'k*',ms=15,label="St. John's, Newfoundland, Canada")
ax.plot(lon_recovery_3, lat_recovery_3,'rs',ms=10,label="Approximate recovery location of Osker 1321")
ax.plot(lon_recovery, lat_recover,'bs',ms=5,label="Approximate recovery location of Osker 1319")
ax.set_xlim([-60,10])
ax.set_ylim([40,65])
pretty_map(ax)
ax.legend(loc=2)
# Out:
# data/OSKERS-SpringAZMP2022-20220526.csv
# /tmp/ipykernel_3246307/1006965679.py:4: DtypeWarning: Columns (381) have mixed types.Specify dtype option on import or set low_memory=False.
#   plot_spotter(spotter, ax)

# %%
fig.savefig('osker-1321-recovery.png', bbox_inches='tight',dpi=300)
